# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df.shape
# Out:
# (126314, 23)

# %%
len(df)
# Out:
# 126314

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df.head(1)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...   40.29483     NYK    Knicks       68
#
#   opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0    1300.0  1306.7233              H            L  0.640065   NaN
#
# [1 rows x 23 columns]

# %%
#head ini sampe 60 aja
df.head(61)
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947   11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947   11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947   11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947   11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947   11/2/1946           1
# ..        ...           ...   ...      ...      ...         ...         ...
# 56         29  194611160PRO   NBA        1     1947  11/16/1946           6
# 57         29  194611160PRO   NBA        0     1947  11/16/1946           7
# 58         30  194611160STB   NBA        0     1947  11/16/1946           6
# 59         30  194611160STB   NBA        1     1947  11/16/1946           3
# 60         31  194611170CLR   NBA        0     1947  11/17/1946           4
#
# ...

# %%
#5 terbawah
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
display(len(df))
# Out:
# 126314

# %%
#nampilin semua baris dan kolom, bukan 10 aja
pd.set_option("display.max_columns", None)

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
#2 angka belakang koma
pd.set_option("display.precision", 2)
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
#melihat type data, apakah ada yg null
#disini date terdeteksi sbg objek harusnya sbg date
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
df.describe(include=['0'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.describe(include=['0'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:10940, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10691 @final
#   10692 def describe(
#   10693     self: NDFrameT,
#    (...)
#   10697     datetime_is_numeric: bool_t = False,
#   10698 ) -> NDFrameT:
#   10699     """
#   10700     Generate descriptive statistics.
#   10701
#    (...)
#   10938     max            NaN      3.0
#   10939     """
# > 10940     return describe_ndframe(
#   10941         obj=self,
#   10942         include=include,
#   10943         exclude=exclude,
#   10944         datetime_is_numeric=datetime_is_numeric,
#   10945         percentiles=percentiles,
#   10946     )
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# ...

# %%
df["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
#mengambil kolom fran id yg datanya lakers
df.loc[df["fran_id"] == 'Lakers', "team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df["fran_id"] == 'Lakers', "team_id"].value_counts().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of LAL    5078
# MNL     946
# Name: team_id, dtype: int64>

# %%
#menampilkan tanggal terakhir si mnl main
df.loc[df["team_id"] == 'MNL', "date_game"].max()
# Out:
# '4/9/1959'

# %%
#agg itu agregate
df.loc[df["team_id"] == 'MNL', "date_game"].agg(('min', 'max'))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
#melihat kolom
df.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
df.columns[0]
# Out:
# 'gameorder'

# %%
#penggunaan loc
#df.loc['rows', 'columns']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'columns'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#ga semua kolom bisa dipanggil pake dot
df.team_id
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %%
#aman nya gini
#df[]
df[df.team_id == 'BOS'].pts.sum()
# Out:
# 626484

# %%
df.loc[df["fran_id"] == 'Lakers', "team_id"].value_counts(normalize=True)*100
# Out:
# LAL    84.3
# MNL    15.7
# Name: team_id, dtype: float64

# %%
revenues = pd.Series([555,7000,9999])
revenues
# Out:
# 0     555
# 1    7000
# 2    9999
# dtype: int64

# %%
type(revenues)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
revenues.values
# Out:
# array([ 555, 7000, 9999], dtype=int64)

# %%
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
city_revenues = pd.Series([555,7000,9999], index=['Jakarta', 'Bandung', 'Pekanbaru'])
city_revenues
# Out:
# Jakarta       555
# Bandung      7000
# Pekanbaru    9999
# dtype: int64

# %%
type(city_revenues.index)
# Out:
# pandas.core.indexes.base.Index

# %%
#dictionary
city_employee_counts = pd.Series({'Jakarta':10, 'Bandung':56, 'Pekanbaru':100})
city_employee_counts
# Out:
# Jakarta       10
# Bandung       56
# Pekanbaru    100
# dtype: int64

# %%
city_employee_counts.keys()
# Out:
# Index(['Jakarta', 'Bandung', 'Pekanbaru'], dtype='object')

# %%
'Jakarta' in city_employee_counts
# Out:
# True

# %%
city_data = pd.DataFrame({
    'revenue':city_revenues,
    'employee_count':city_employee_counts
    
})

city_data
# Out:
#            revenue  employee_count
# Jakarta        555              10
# Bandung       7000              56
# Pekanbaru     9999             100

# %%
city_data.index

# %%
city_data.values

# %%
city_data.axes
# Out:
# [Index(['Jakarta', 'Bandung', 'Pekanbaru'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
city_data.axes[0]
#0 itu baris 1 itu kolom
# Out:
# Index(['Jakarta', 'Bandung', 'Pekanbaru'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
'revenue' in city_data
# Out:
# True

# %%
'Bandung' in city_data
# Out:
# False

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
'pts' in df
# Out:
# True

# %%
#utk mengakses data ada .loc dan .iloc

# %%
#label index
city_revenues['Jakarta']
# Out:
# 555

# %%
#integer index
city_revenues[0]
# Out:
# 555

# %%
city_revenues[:2]
# Out:
# Jakarta     555
# Bandung    7000
# dtype: int64

# %%
city_revenues['Bandung':]
# Out:
# Bandung      7000
# Pekanbaru    9999
# dtype: int64

# %%
colors = pd.Series(
    ['red', 'purple', 'blue', 'green', 'yellow'],
    index = [1,2,3,5,8]
)
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors[8]
# Out:
# 'yellow'

# %%
#loc menggunakan label index
colors.loc[2]
# Out:
# 'purple'

# %%
#iloc menggunakan positional index
colors.iloc[2]
# Out:
# 'blue'

# %%
colors.iloc[1:3]
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
colors.loc[3:8]
# Out:
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
city_data['revenue']
# Out:
# Jakarta       555
# Bandung      7000
# Pekanbaru    9999
# Name: revenue, dtype: int64

# %% [markdown]
# ## Akses Dataframe elemen

# %%
toys = pd.DataFrame([{"name": "ball", "shape":"sphere"}, {"name": "Rubik's cube", "shape": "cube"}])
toys
# Out:
#            name   shape
# 0          ball  sphere
# 1  Rubik's cube    cube

# %%
toys.name
# Out:
# 0            ball
# 1    Rubik's cube
# Name: name, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %%
city_data.loc['Bandung']
# Out:
# revenue           7000
# employee_count      56
# Name: Bandung, dtype: int64

# %%
city_data
# Out:
#            revenue  employee_count
# Jakarta        555              10
# Bandung       7000              56
# Pekanbaru     9999             100

# %%
city_data.iloc[0]
# Out:
# revenue           555
# employee_count     10
# Name: Jakarta, dtype: int64

# %%
city_data.loc['Jakarta':'Pekanbaru']
# Out:
#            revenue  employee_count
# Jakarta        555              10
# Bandung       7000              56
# Pekanbaru     9999             100

# %%
city_data.iloc[1:3]
# Out:
#            revenue  employee_count
# Bandung       7000              56
# Pekanbaru     9999             100

# %%
df.iloc[-2]
# Out:
# gameorder               63157
# game_id          201506170CLE
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           6/16/2015
# seasongame                102
# is_playoffs                 1
# team_id                   CLE
# fran_id             Cavaliers
# pts                        97
# elo_i                 1700.74
# elo_n                 1692.09
# win_equiv               59.29
# opp_id                    GSW
# opp_fran             Warriors
# opp_pts                   105
# opp_elo_i             1813.63
# opp_elo_n             1822.29
# game_location               H
# game_result                 L
# forecast                 0.48
# notes                     NaN
# Name: 126312, dtype: object

# %%
df.iloc[-2, 1]
# Out:
# '201506170CLE'

# %%
df.loc[126312, 'game_id']
# Out:
# '201506170CLE'

# %%
df.loc[126312, 'game_id': 'year_id']
# Out:
# game_id    201506170CLE
# lg_id               NBA
# _iscopy               0
# year_id            2015
# Name: 126312, dtype: object

# %%
df.loc[126312, ['game_id','game_result', 'team_id', 'opp_id']]
# Out:
# game_id        201506170CLE
# game_result               L
# team_id                 CLE
# opp_id                  GSW
# Name: 126312, dtype: object

# %%
df[df['year_id'] > 2010]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
current_decade = df[df['year_id'] > 2010]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
df[df.notes.notnull()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
df[df.notes.notna()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
df[df.fran_id.str.endswith('ers')]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# ...

# %%
df[(df.fran_id.str.endswith('ers'))& (df.notes.notnull()) & (df.year_id >= 2000) & (df['_iscopy'] == 0)]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 95379       47690  200310300SEA   NBA        0     2004  10/30/2003
# 95384       47693  200310310LAC   NBA        0     2004  10/31/2003
# 110348      55175  200903130PHI   NBA        0     2009   3/13/2009
#
#         seasongame  is_playoffs team_id   fran_id  ...  win_equiv  opp_id  \
# 95379            1            0     LAC  Clippers  ...  32.555450     SEA
# 95384            2            0     LAC  Clippers  ...  31.541140     SEA
# 110348          63            0     PHI    Sixers  ...  41.889912     CHI
#
#         opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# 95379    Thunder      109  1523.1268  1529.7584              N            L
# 95384    Thunder      124  1529.7584  1539.9128              N            L
# 110348     Bulls      101  1482.2396  1478.9159              H            W
#
#         forecast                                    notes
# ...

# %%
#yg ini belum beres
df[(df['team_id'].str.startswith('LA')) & (df.year_id == 1992)]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 66638      33320  199111010HOU   NBA        1     1992  11/1/1991           1
# 66649      33325  199111010SAC   NBA        1     1992  11/1/1991           1
# 66659      33330  199111020DAL   NBA        1     1992  11/2/1991           2
# 66667      33334  199111020LAC   NBA        0     1992  11/2/1991           2
# 66692      33347  199111050LAL   NBA        0     1992  11/5/1991           3
# ...          ...           ...   ...      ...      ...        ...         ...
# 68881      34441  199204280LAC   NBA        0     1992  4/28/1992          85
# 68887      34444  199204290LAL   NBA        0     1992  4/29/1992          85
# 68901      34451  199205030LAC   NBA        0     1992   5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992   5/3/1992          86
# 68908      34455  199205040UTA   NBA        1     1992   5/4/1992          87
#
# ...

# %% [markdown]
# ## Grouping dan Agregasi

# %%
poin = df['pts']
poin.sum()
# Out:
# 12976235

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df.groupby('fran_id')['pts'].sum()
# Out:
# fran_id
# Baltimore        37219
# Bombers          17793
# Bucks           418326
# Bulls           437269
# Capitols         22387
# Cavaliers       380416
# Celtics         626484
# Clippers        380523
# Colonels         94435
# Condors          49642
# Denver            4818
# Falcons           3797
# Floridians       49568
# Grizzlies       157683
# Hawks           567261
# Heat            229103
# Hornets          84489
# Huskies           3995
# Ironmen           3674
# Jazz            363155
# Jets              4482
# Kings           569245
# Knicks          582497
# Lakers          637444
# Magic           219436
# Mavericks       309239
# Nets            417809
# Nuggets         445780
# Olympians        22864
# Pacers          438288
# Packers           6193
# Pelicans        220794
# Pistons         572758
# Raptors         158370
# Rebels            4474
# Redskins          5372
# Rockets         432504
# Sails            30080
# Sixers          585891
# ...

# %%
df.groupby('fran_id', sort = Fal)['pts'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.groupby('fran_id', sort = Fal)['pts'].sum()
#
# NameError: name 'Fal' is not defined

# %% [markdown]
# ## Manipulasi kolom

# %%
nba = df.copy()
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
nba['difference'] = nba.pts - nba.opp_pts
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...

# %%
nba['difference'].max()
# Out:
# 68

# %%
renames_nba = nba.rename(columns = {"game_result":"result", "game_location":"location"}, inplace = True)
renames_nba

# %%
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...

# %%
# menghapus kolom
elo.columns = ['elo_i', 'elo_n', 'opp_elo_i', 'opp_elo_n']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # menghapus kolom
# ----> 2 elo.columns = ['elo_i', 'elo_n', 'opp_elo_i', 'opp_elo_n']
#
# NameError: name 'elo' is not defined

# %% [markdown]
# ### Data types

# %%
nba['date_game'] = pd.to_datetime(nba['date_game'])
nba['date_game'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 126314 entries, 0 to 126313
# Series name: date_game
# Non-Null Count   Dtype
# --------------   -----
# 126314 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 987.0 KB

# %%
nba.location.nunique()
# Out:
# 3

# %%
nba.location.value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: location, dtype: int64

# %%
nba.location.dtype
# Out:
# dtype('O')

# %%
nba.location = pd.Categorical(nba.location)
nba.location.dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %%
non_null_notes = nba.dropna()
non_null_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 930           466  194801300BLB   NBA        1     1948 1948-01-30
# 931           466  194801300BLB   NBA        0     1948 1948-01-30
# 1084          543  194803230CHS   NBA        1     1948 1948-03-23
# 1085          543  194803230CHS   NBA        0     1948 1948-03-23
# 1088          545  194803250CHS   NBA        1     1948 1948-03-25
# ...           ...           ...   ...      ...      ...        ...
# 122207      61104  201401160ATL   NBA        0     2014 2014-01-16
# 123916      61959  201411120MIN   NBA        1     2015 2014-11-12
# 123917      61959  201411120MIN   NBA        0     2015 2014-11-12
# 124862      62432  201501150MIL   NBA        0     2015 2015-01-15
# 124863      62432  201501150MIL   NBA        1     2015 2015-01-15
#
#         seasongame  is_playoffs team_id       fran_id  ...  opp_id  \
# 930             28            0     WSC      Capitols  ...     BLB
# ...

# %%
data_without_missing_columns = nba.dropna(axis = 1)
data_without_missing_columns
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
data_with_default_notes = nba.copy()
data_with_default_notes['notes'].fillna(
    value = "no notes at all",
    inplace = True
)
data_with_default_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...

# %%
data_with_default_notes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  datetime64[ns]
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  elo_i        126314 non-null  float64
#  12  elo_n        126314 non-null  float64
#  13  win_equiv    126314 non-null  float64
#  14  opp_id       126314 non-null  object
#  15  opp_fran     126314 non-null  object
#  16  opp_pts      126314 non-null  int64
#  17  opp_elo_i    126314 non-null  float64
# ...

# %% [markdown]
# ### invalid values

# %%
nba.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %% [markdown]
# ## Combine

# %%
further_city_data = pd. dataFrame(
    {"revenue": [7000, 3400], "employee_count": []}
)
